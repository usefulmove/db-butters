# %%
import duckdb
import altair as alt

alt.theme.enable('ggplot2')

jco_colors = [
    "#0073C2",  # blue
    "#EFC000",  # yellow
    "#868686",  # gray
    "#CD534C",  # red
    "#7AA6DC",  # light blue
    "#003C67",  # dark blue
    "#8F7700",  # dark yellow
    "#3B3B3B",  # dark gray
    "#A73030",  # dark red
    "#4A6990",  # slate blue
]

# %% [markdown]
# ## load data

# %%
uri = 'https://raw.githubusercontent.com/rfordatascience/tidytuesday/main/data/2025/2025-11-18/who_tb_data.csv'

tb_data = duckdb.sql(f"from read_csv('{uri}', nullstr=['', 'NA']);").pl()

# %%
tb_data
# Out:
# shape: (5_117, 18)
# ┌────────────┬────────────┬────────────┬──────┬───┬────────────┬───────────┬───────────┬───────────┐
# │ country    ┆ g_whoregio ┆ iso_numeri ┆ iso2 ┆ … ┆ e_mort_num ┆ e_mort_tb ┆ e_mort_tb ┆ e_pop_num │
# │ ---        ┆ n          ┆ c          ┆ ---  ┆   ┆ ---        ┆ hiv_100k  ┆ hiv_num   ┆ ---       │
# │ str        ┆ ---        ┆ ---        ┆ str  ┆   ┆ i64        ┆ ---       ┆ ---       ┆ i64       │
# │            ┆ str        ┆ i64        ┆      ┆   ┆            ┆ f64       ┆ i64       ┆           │
# ╞════════════╪════════════╪════════════╪══════╪═══╪════════════╪═══════════╪═══════════╪═══════════╡
# │ Afghanista ┆ Eastern    ┆ 4          ┆ AF   ┆ … ┆ 14000      ┆ 0.17      ┆ 34        ┆ 20130323  │
# │ n          ┆ Mediterran ┆            ┆      ┆   ┆            ┆           ┆           ┆           │
# │            ┆ ean        ┆            ┆      ┆   ┆            ┆           ┆           ┆           │
# │ Afghanista ┆ Eastern    ┆ 4          ┆ AF   ┆ … ┆ 13000      ┆ 0.3       ┆ 61        ┆ 20284311  │
# │ n          ┆ Mediterran ┆            ┆      ┆   ┆            ┆           ┆           ┆           │
# │            ┆ ean        ┆            ┆      ┆   ┆            ┆           ┆           ┆           │
# │ Afghanista ┆ Eastern    ┆ 4          ┆ AF   ┆ … ┆ 12000      ┆ 0.27      ┆ 58        ┆ 21378110  │
# │ n          ┆ Mediterran ┆            ┆      ┆   ┆            ┆           ┆           ┆           │
# │            ┆ ean        ┆            ┆      ┆   ┆            ┆           ┆           ┆           │
# │ Afghanista ┆ Eastern    ┆ 4          ┆ AF   ┆ … ┆ 13000      ┆ 0.29      ┆ 66        ┆ 22733047  │
# │ n          ┆ Mediterran ┆            ┆      ┆   ┆            ┆           ┆           ┆           │
# │            ┆ ean        ┆            ┆      ┆   ┆            ┆           ┆           ┆           │
# │ Afghanista ┆ Eastern    ┆ 4          ┆ AF   ┆ … ┆ 12000      ┆ 0.29      ┆ 67        ┆ 23560660  │
# │ n          ┆ Mediterran ┆            ┆      ┆   ┆            ┆           ┆           ┆           │
# │            ┆ ean        ┆            ┆      ┆   ┆            ┆           ┆           ┆           │
# │ …          ┆ …          ┆ …          ┆ …    ┆ … ┆ …          ┆ …         ┆ …         ┆ …         │
# │ Zimbabwe   ┆ Africa     ┆ 716        ┆ ZW   ┆ … ┆ 6500       ┆ 31.0      ┆ 4800      ┆ 15271376  │
# │ Zimbabwe   ┆ Africa     ┆ 716        ┆ ZW   ┆ … ┆ 6800       ┆ 31.0      ┆ 4800      ┆ 15526885  │
# │ Zimbabwe   ┆ Africa     ┆ 716        ┆ ZW   ┆ … ┆ 7800       ┆ 34.0      ┆ 5400      ┆ 15797209  │
# │ Zimbabwe   ┆ Africa     ┆ 716        ┆ ZW   ┆ … ┆ 8400       ┆ 37.0      ┆ 5900      ┆ 16069054  │
# │ Zimbabwe   ┆ Africa     ┆ 716        ┆ ZW   ┆ … ┆ 7900       ┆ 34.0      ┆ 5500      ┆ 16340822  │
# └────────────┴────────────┴────────────┴──────┴───┴────────────┴───────────┴───────────┴───────────┘

# %% [markdown]
# ## exporation

# %%
duckdb.sql("""
--sqlbegin

    select iso3,
           country,
           g_whoregion,
           round(avg(e_mort_100k), 2) estimated_mortality_rate
    from tb_data
    group by 1, 2, 3
    order by 4 desc

--sqlend
""")
# Out:
# ┌─────────┬──────────────────────────────────────────────────────────┬───────────────────────┬──────────────────────────┐
# │  iso3   │                         country                          │      g_whoregion      │ estimated_mortality_rate │
# │ varchar │                         varchar                          │        varchar        │          double          │
# ├─────────┼──────────────────────────────────────────────────────────┼───────────────────────┼──────────────────────────┤
# │ LSO     │ Lesotho                                                  │ Africa                │                   332.92 │
# │ SWZ     │ Eswatini                                                 │ Africa                │                   284.75 │
# │ ZAF     │ South Africa                                             │ Africa                │                   235.88 │
# │ NAM     │ Namibia                                                  │ Africa                │                   217.21 │
# │ CAF     │ Central African Republic                                 │ Africa                │                   214.67 │
# │ GAB     │ Gabon                                                    │ Africa                │                   155.17 │
# │ KEN     │ Kenya                                                    │ Africa                │                   147.88 │
# │ TZA     │ United Republic of Tanzania                              │ Africa                │                   140.79 │
# │ GNB     │ Guinea-Bissau                                            │ Africa                │                   131.42 │
# │ ZMB     │ Zambia                                                   │ Africa                │                   122.21 │
# │  ·      │   ·                                                      │   ·                   │                       ·  │
# │  ·      │   ·                                                      │   ·                   │                       ·  │
# │  ·      │   ·                                                      │   ·                   │                       ·  │
# │ JOR     │ Jordan                                                   │ Eastern Mediterranean │                     0.31 │
# │ USA     │ United States of America                                 │ Americas              │                      0.3 │
# │ AUS     │ Australia                                                │ Western Pacific       │                     0.29 │
# │ BMU     │ Bermuda                                                  │ Americas              │                     0.28 │
# │ SYR     │ Syrian Arab Republic                                     │ Eastern Mediterranean │                     0.23 │
# │ VGB     │ British Virgin Islands                                   │ Americas              │                      0.2 │
# │ PSE     │ occupied Palestinian territory, including east Jerusalem │ Eastern Mediterranean │                     0.12 │
# │ MCO     │ Monaco                                                   │ Europe                │                     0.08 │
# │ SMR     │ San Marino                                               │ Europe                │                      0.0 │
# │ PRK     │ Democratic People's Republic of Korea                    │ South-East Asia       │                     NULL │
# ├─────────┴──────────────────────────────────────────────────────────┴───────────────────────┴──────────────────────────┤
# │ 215 rows (20 shown)                                                                                         4 columns │
# └───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┘

# %%
duckdb.sql("""
--sqlbegin

    select iso3,
           country,
           g_whoregion,
           round(max(e_mort_100k) - min(e_mort_100k), 2) as estimated_mortality_change
    from tb_data
    group by 1, 2, 3
    order by 4 desc

--sqlend
""")
# Out:
# ┌─────────┬──────────────────────────────────────────────────────────┬───────────────────────┬────────────────────────────┐
# │  iso3   │                         country                          │      g_whoregion      │ estimated_mortality_change │
# │ varchar │                         varchar                          │        varchar        │           double           │
# ├─────────┼──────────────────────────────────────────────────────────┼───────────────────────┼────────────────────────────┤
# │ SWZ     │ Eswatini                                                 │ Africa                │                      456.0 │
# │ ZAF     │ South Africa                                             │ Africa                │                      352.0 │
# │ NAM     │ Namibia                                                  │ Africa                │                      263.0 │
# │ LSO     │ Lesotho                                                  │ Africa                │                      261.0 │
# │ BWA     │ Botswana                                                 │ Africa                │                      222.0 │
# │ ZMB     │ Zambia                                                   │ Africa                │                      205.0 │
# │ TZA     │ United Republic of Tanzania                              │ Africa                │                      198.0 │
# │ KEN     │ Kenya                                                    │ Africa                │                      194.0 │
# │ CAF     │ Central African Republic                                 │ Africa                │                      155.0 │
# │ CIV     │ Côte d'Ivoire                                            │ Africa                │                      154.0 │
# │  ·      │    ·                                                     │   ·                   │                         ·  │
# │  ·      │    ·                                                     │   ·                   │                         ·  │
# │  ·      │    ·                                                     │   ·                   │                         ·  │
# │ TUN     │ Tunisia                                                  │ Eastern Mediterranean │                        0.4 │
# │ CAN     │ Canada                                                   │ Americas              │                       0.38 │
# │ SYR     │ Syrian Arab Republic                                     │ Eastern Mediterranean │                       0.38 │
# │ AUS     │ Australia                                                │ Western Pacific       │                       0.35 │
# │ PSE     │ occupied Palestinian territory, including east Jerusalem │ Eastern Mediterranean │                       0.31 │
# │ IRN     │ Iran (Islamic Republic of)                               │ Eastern Mediterranean │                       0.31 │
# │ MCO     │ Monaco                                                   │ Europe                │                       0.29 │
# │ CUB     │ Cuba                                                     │ Americas              │                       0.23 │
# │ SMR     │ San Marino                                               │ Europe                │                        0.0 │
# │ PRK     │ Democratic People's Republic of Korea                    │ South-East Asia       │                       NULL │
# ├─────────┴──────────────────────────────────────────────────────────┴───────────────────────┴────────────────────────────┤
# │ 215 rows (20 shown)                                                                                           4 columns │
# └─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┘

# %%
duckdb.sql("""
--sqlbegin

    select iso3,
           country,
           g_whoregion,
           round(max(e_inc_100k) - min(e_inc_100k), 2) as estimated_incidence_change
    from tb_data
    group by 1, 2, 3
    order by 4 desc

--sqlend
""")
# Out:
# ┌─────────┬───────────────────────────────────────┬───────────────────────┬────────────────────────────┐
# │  iso3   │                country                │      g_whoregion      │ estimated_incidence_change │
# │ varchar │                varchar                │        varchar        │           double           │
# ├─────────┼───────────────────────────────────────┼───────────────────────┼────────────────────────────┤
# │ SWZ     │ Eswatini                              │ Africa                │                     1250.0 │
# │ MHL     │ Marshall Islands                      │ Western Pacific       │                     1096.0 │
# │ ZAF     │ South Africa                          │ Africa                │                      843.0 │
# │ NAM     │ Namibia                               │ Africa                │                      805.0 │
# │ BWA     │ Botswana                              │ Africa                │                      677.0 │
# │ LSO     │ Lesotho                               │ Africa                │                      631.0 │
# │ DJI     │ Djibouti                              │ Eastern Mediterranean │                      488.0 │
# │ ZMB     │ Zambia                                │ Africa                │                      476.0 │
# │ ZWE     │ Zimbabwe                              │ Africa                │                      429.0 │
# │ KEN     │ Kenya                                 │ Africa                │                      423.0 │
# │  ·      │   ·                                   │   ·                   │                         ·  │
# │  ·      │   ·                                   │   ·                   │                         ·  │
# │  ·      │   ·                                   │   ·                   │                         ·  │
# │ AIA     │ Anguilla                              │ Americas              │                        2.0 │
# │ CAN     │ Canada                                │ Americas              │                        1.9 │
# │ AUS     │ Australia                             │ Western Pacific       │                        1.7 │
# │ TLS     │ Timor-Leste                           │ South-East Asia       │                        0.0 │
# │ CAF     │ Central African Republic              │ Africa                │                        0.0 │
# │ PRK     │ Democratic People's Republic of Korea │ South-East Asia       │                        0.0 │
# │ NGA     │ Nigeria                               │ Africa                │                        0.0 │
# │ BGD     │ Bangladesh                            │ South-East Asia       │                        0.0 │
# │ SSD     │ South Sudan                           │ Africa                │                        0.0 │
# │ PNG     │ Papua New Guinea                      │ Western Pacific       │                        0.0 │
# ├─────────┴───────────────────────────────────────┴───────────────────────┴────────────────────────────┤
# │ 215 rows (20 shown)                                                                        4 columns │
# └──────────────────────────────────────────────────────────────────────────────────────────────────────┘

# %% [markdown]
# ## highest estimated mortality rates and trends

# %%
df = duckdb.sql("""
--sqlbegin

    with countries_iso3 as (
            select iso3,
                   round(avg(e_inc_100k), 2)
                   --max(e_mort_100k) - min(e_mort_100k)
            from tb_data
            --where year between 2018 and 2023
            group by 1
            order by 2 desc
            limit 8
    )

    from tb_data
    where iso3 in (select iso3 from countries_iso3)

--sqlend
""")

display(df)

alt.Chart(
    df,
    width=850,
    height=650,
).mark_line(
    size=4.0,
    opacity=0.8,
    #point={'size': 50},
    interpolate='catmull-rom',
).encode(
    x='year',
    y='e_inc_100k',
    color=alt.Color('country', scale=alt.Scale(scheme='set2')),
)
# Out:
# ┌──────────────────────────┬─────────────┬─────────────┬─────────┬─────────┬───────┬────────┬───────────────┬────────┬────────────┬───────────┬─────────────┬───────────────────────┬──────────────────────┬────────────┬───────────────────┬──────────────────┬───────────┐
# │         country          │ g_whoregion │ iso_numeric │  iso2   │  iso3   │ year  │ c_cdr  │ c_newinc_100k │  cfr   │ e_inc_100k │ e_inc_num │ e_mort_100k │ e_mort_exc_tbhiv_100k │ e_mort_exc_tbhiv_num │ e_mort_num │ e_mort_tbhiv_100k │ e_mort_tbhiv_num │ e_pop_num │
# │         varchar          │   varchar   │    int64    │ varchar │ varchar │ int64 │ double │    double     │ double │   double   │   int64   │   double    │        double         │        int64         │   int64    │      double       │      int64       │   int64   │
# ├──────────────────────────┼─────────────┼─────────────┼─────────┼─────────┼───────┼────────┼───────────────┼────────┼────────────┼───────────┼─────────────┼───────────────────────┼──────────────────────┼────────────┼───────────────────┼──────────────────┼───────────┤
# │ Central African Republic │ Africa      │         140 │ CF      │ CAF     │  2000 │   NULL │          NULL │   0.57 │      540.0 │     21000 │       295.0 │                  81.0 │                 3100 │      11000 │             215.0 │             8200 │   3833419 │
# │ Central African Republic │ Africa      │         140 │ CF      │ CAF     │  2001 │   12.0 │          65.0 │   0.57 │      540.0 │     21000 │       297.0 │                  94.0 │                 3700 │      12000 │             203.0 │             8000 │   3919495 │
# │ Central African Republic │ Africa      │         140 │ CF      │ CAF     │  2002 │   22.0 │         121.0 │    0.5 │      540.0 │     22000 │       259.0 │                  89.0 │                 3600 │      10000 │             169.0 │             6800 │   4006073 │
# │ Central African Republic │ Africa      │         140 │ CF      │ CAF     │  2003 │   18.0 │          96.0 │   0.52 │      540.0 │     22000 │       269.0 │                  98.0 │                 4000 │      11000 │             171.0 │             7000 │   4103088 │
# │ Central African Republic │ Africa      │         140 │ CF      │ CAF     │  2004 │   17.0 │          93.0 │   0.52 │      540.0 │     23000 │       269.0 │                 101.0 │                 4200 │      11000 │             169.0 │             7100 │   4192826 │
# │ Central African Republic │ Africa      │         140 │ CF      │ CAF     │  2005 │   14.0 │          75.0 │   0.54 │      540.0 │     23000 │       281.0 │                 103.0 │                 4400 │      12000 │             178.0 │             7600 │   4288809 │
# │ Central African Republic │ Africa      │         140 │ CF      │ CAF     │  2006 │   26.0 │         138.0 │   0.47 │      540.0 │     24000 │       247.0 │                  87.0 │                 3800 │      11000 │             160.0 │             7000 │   4377583 │
# │ Central African Republic │ Africa      │         140 │ CF      │ CAF     │  2007 │   NULL │          NULL │   0.48 │      540.0 │     24000 │       249.0 │                  86.0 │                 3800 │      11000 │             163.0 │             7300 │   4462763 │
# │ Central African Republic │ Africa      │         140 │ CF      │ CAF     │  2008 │   28.0 │         149.0 │   0.46 │      540.0 │     25000 │       240.0 │                  84.0 │                 3800 │      11000 │             156.0 │             7100 │   4558988 │
# │ Central African Republic │ Africa      │         140 │ CF      │ CAF     │  2009 │   36.0 │         193.0 │   0.41 │      540.0 │     24000 │       215.0 │                  77.0 │                 3500 │       9700 │             138.0 │             6200 │   4529048 │
# │      ·                   │   ·         │          ·  │ ·       │  ·      │    ·  │     ·  │           ·   │     ·  │        ·   │       ·   │         ·   │                    ·  │                   ·  │         ·  │                ·  │               ·  │      ·    │
# │      ·                   │   ·         │          ·  │ ·       │  ·      │    ·  │     ·  │           ·   │     ·  │        ·   │       ·   │         ·   │                    ·  │                   ·  │         ·  │                ·  │               ·  │      ·    │
# │      ·                   │   ·         │          ·  │ ·       │  ·      │    ·  │     ·  │           ·   │     ·  │        ·   │       ·   │         ·   │                    ·  │                   ·  │         ·  │                ·  │               ·  │      ·    │
# │ South Africa             │ Africa      │         710 │ ZA      │ ZAF     │  2014 │   52.0 │         551.0 │   0.13 │     1070.0 │    594000 │       124.0 │                  37.0 │                21000 │      69000 │              87.0 │            48000 │  55594839 │
# │ South Africa             │ Africa      │         710 │ ZA      │ ZAF     │  2015 │   51.0 │         506.0 │   0.13 │      988.0 │    561000 │       116.0 │                  36.0 │                20000 │      66000 │              80.0 │            45000 │  56723532 │
# │ South Africa             │ Africa      │         710 │ ZA      │ ZAF     │  2016 │   51.0 │         414.0 │   0.15 │      805.0 │    461000 │       112.0 │                  36.0 │                21000 │      64000 │              76.0 │            43000 │  57259553 │
# │ South Africa             │ Africa      │         710 │ ZA      │ ZAF     │  2017 │   57.0 │         422.0 │   0.15 │      738.0 │    426000 │       106.0 │                  37.0 │                21000 │      61000 │              70.0 │            40000 │  57635157 │
# │ South Africa             │ Africa      │         710 │ ZA      │ ZAF     │  2018 │   57.0 │         389.0 │   0.16 │      677.0 │    397000 │       103.0 │                  37.0 │                22000 │      60000 │              66.0 │            39000 │  58613004 │
# │ South Africa             │ Africa      │         710 │ ZA      │ ZAF     │  2019 │   57.0 │         352.0 │   0.17 │      615.0 │    366000 │        99.0 │                  38.0 │                22000 │      59000 │              62.0 │            37000 │  59587889 │
# │ South Africa             │ Africa      │         710 │ ZA      │ ZAF     │  2020 │   56.0 │         315.0 │   0.18 │      562.0 │    340000 │        96.0 │                  38.0 │                23000 │      58000 │              58.0 │            35000 │  60562386 │
# │ South Africa             │ Africa      │         710 │ ZA      │ ZAF     │  2021 │   55.0 │         280.0 │   0.19 │      513.0 │    315000 │        93.0 │                  38.0 │                24000 │      57000 │              55.0 │            34000 │  61502602 │
# │ South Africa             │ Africa      │         710 │ ZA      │ ZAF     │  2022 │   73.0 │         344.0 │    0.2 │      468.0 │    292000 │        90.0 │                  39.0 │                24000 │      56000 │              52.0 │            32000 │  62378415 │
# │ South Africa             │ Africa      │         710 │ ZA      │ ZAF     │  2023 │   79.0 │         335.0 │   0.22 │      427.0 │    270000 │        88.0 │                  39.0 │                25000 │      56000 │              49.0 │            31000 │  63212382 │
# ├──────────────────────────┴─────────────┴─────────────┴─────────┴─────────┴───────┴────────┴───────────────┴────────┴────────────┴───────────┴─────────────┴───────────────────────┴──────────────────────┴────────────┴───────────────────┴──────────────────┴───────────┤
# │ 192 rows (20 shown)                                                                                                                                                                                                                                           18 columns │
# └──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┘
# alt.Chart(...)

# %%
df = duckdb.sql("""
--sqlbegin

    with countries_iso3 as (
            select iso3,
                   country,
                   g_whoregion,
                   round(avg(e_inc_100k), 2) as metric
                   --max(e_mort_100k) - min(e_mort_100k) as metric
            from tb_data
            --where year between 2018 and 2023
            group by 1, 2, 3
            order by metric desc
            limit 8
    )

    from countries_iso3

--sqlend
""")

display(df)
# Out:
# ┌─────────┬───────────────────────────────────────┬─────────────────┬────────┐
# │  iso3   │                country                │   g_whoregion   │ metric │
# │ varchar │                varchar                │     varchar     │ double │
# ├─────────┼───────────────────────────────────────┼─────────────────┼────────┤
# │ SWZ     │ Eswatini                              │ Africa          │  947.5 │
# │ ZAF     │ South Africa                          │ Africa          │ 943.46 │
# │ LSO     │ Lesotho                               │ Africa          │ 930.42 │
# │ NAM     │ Namibia                               │ Africa          │ 830.13 │
# │ PHL     │ Philippines                           │ Western Pacific │ 555.63 │
# │ GAB     │ Gabon                                 │ Africa          │ 547.17 │
# │ CAF     │ Central African Republic              │ Africa          │  540.0 │
# │ PRK     │ Democratic People's Republic of Korea │ South-East Asia │  513.0 │
# └─────────┴───────────────────────────────────────┴─────────────────┴────────┘

# %%
df = duckdb.sql("""
--sqlbegin

select g_whoregion as region,
       year,
       round(avg(e_inc_100k), 2) as avg_e_inc_100k
from tb_data
group by 1, 2

--sqlend
""").pl()

import polars as pl

min_year = df.select(pl.col('year').min()).item()
max_year = df.select(pl.col('year').max()).item()

alt.Chart(
    df,
    width=700,
    height=600,
    title=alt.Title(
        f'Estimated incidence of tuberculosis ({min_year} to {max_year})',
        fontSize=18.5, fontWeight='normal',
        subtitle='Incidence has decreased but we see recent increases in some regions',
        subtitleFontSize=15,
    ),
).mark_line(
    size=3.8,
    opacity=0.7,
    interpolate='catmull-rom',
).encode(
    x=alt.X(
        'year',
         title='',
         axis=alt.Axis(format='d', values=list(range(min_year, max_year+1, 2))),
    ),
    y=alt.Y(
        'avg_e_inc_100k',
        title='incidence per 100,000 people (estimated)',
        axis=alt.Axis(values=range(0, 400+1, 20))
    ),
    color=alt.Color(
        'region',
        title='',
        scale=alt.Scale(range=jco_colors),
    ),
    tooltip='region',
)
# Out:
# alt.Chart(...)
